# %%
# %%bash
#
# #pip install -I mxnet-cu80==0.12.0
# #pip list
# cd incubator-mxnet/example/ssd/
# #python3 train.py --data-shape 512 --finetune 1 --end-epoch 20 --num-class 2 --class-names 'nike, adidas' --num-example 108
# python3 train.py --data-shape 512 --resume 20 --end-epoch 40 --num-class 2 --class-names 'nike, adidas' --num-example 108
# #python3 train.py --data-shape 512 --resume 40 --end-epoch 60 --num-class 3 --class-names 'nike, adidas' --num-example 108
# #df -k
# #du -a /home/ec2-user/SageMaker/incubator-mxnet/ | sort -n -r | head -n 5
# Out:
# [14:04:23] src/io/iter_image_det_recordio.cc:280: ImageDetRecordIOParser: /home/ec2-user/SageMaker/incubator-mxnet/example/ssd/data/train.rec, use 3 threads for decoding..
# [14:04:23] src/io/iter_image_det_recordio.cc:333: ImageDetRecordIOParser: /home/ec2-user/SageMaker/incubator-mxnet/example/ssd/data/train.rec, label padding width: 350
# [14:04:24] src/io/iter_image_det_recordio.cc:280: ImageDetRecordIOParser: /home/ec2-user/SageMaker/incubator-mxnet/example/ssd/data/val.rec, use 3 threads for decoding..
# [14:04:24] src/io/iter_image_det_recordio.cc:333: ImageDetRecordIOParser: /home/ec2-user/SageMaker/incubator-mxnet/example/ssd/data/val.rec, label padding width: 350
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
# ...

# %%
# %%bash
# cd incubator-mxnet/example/ssd/
# # python3 evaluate.py --epoch 5 --data-shape 512 --num-class 3 --class-names 'nike, nikeText, adidas'
# # python3 evaluate.py --epoch 10 --data-shape 512 --num-class 3 --class-names 'nike, nikeText, adidas'
# # python3 evaluate.py --epoch 15 --data-shape 512 --num-class 3 --class-names 'nike, nikeText, adidas'
# # python3 evaluate.py --epoch 20 --data-shape 512 --num-class 3 --class-names 'nike, nikeText, adidas'
# # python3 evaluate.py --epoch 25 --data-shape 512 --num-class 3 --class-names 'nike, nikeText, adidas'
# # python3 evaluate.py --epoch 30 --data-shape 512 --num-class 3 --class-names 'nike, nikeText, adidas'
# python3 evaluate.py --epoch 39 --data-shape 512 --num-class 2 --class-names 'nike, adidas'
# python3 evaluate.py --epoch 40 --data-shape 512 --num-class 2 --class-names 'nike, adidas'
# # python3 evaluate.py --epoch 45 --data-shape 512 --num-class 3 --class-names 'nike, nikeText, adidas'
# # python3 evaluate.py --epoch 50 --data-shape 512 --num-class 3 --class-names 'nike, nikeText, adidas'
# # python3 evaluate.py --epoch 55 --data-shape 512 --num-class 3 --class-names 'nike, nikeText, adidas'
# # python3 evaluate.py --epoch 60 --data-shape 512 --num-class 3 --class-names 'nike, nikeText, adidas'
# Out:
# nike: 0.8089126559714795
# adidas: 0.9740259740259742
# mAP: 0.891469314998727
# nike: 0.941940412528648
# adidas: 0.9740259740259742
# mAP: 0.9579831932773111
# [14:10:25] src/io/iter_image_det_recordio.cc:280: ImageDetRecordIOParser: /home/ec2-user/SageMaker/incubator-mxnet/example/ssd/data/val.rec, use 3 threads for decoding..
# [14:10:25] src/io/iter_image_det_recordio.cc:333: ImageDetRecordIOParser: /home/ec2-user/SageMaker/incubator-mxnet/example/ssd/data/val.rec, label padding width: 14
# [14:10:27] src/operator/././cudnn_algoreg-inl.h:106: Running performance tests to find the best convolution algorithm, this can take a while... (setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
# ...

# %%
# %%bash
#
# cd incubator-mxnet/example/ssd/
# pip list
# python3 deploy.py --epoch 40 --num-class 2
# Out:
# alabaster (0.7.10)
# anaconda-client (1.6.5)
# anaconda-navigator (1.6.9)
# anaconda-project (0.8.0)
# asn1crypto (0.22.0)
# astroid (1.5.3)
# astropy (2.0.2)
# awscli (1.14.22)
# Babel (2.5.0)
# backports.functools-lru-cache (1.4)
# backports.shutil-get-terminal-size (1.0.0)
# beautifulsoup4 (4.6.0)
# bitarray (0.8.1)
# bkcharts (0.2)
# blaze (0.11.3)
# bleach (2.0.0)
# bokeh (0.12.10)
# boto (2.48.0)
# boto3 (1.5.12)
# botocore (1.8.26)
# Bottleneck (1.2.1)
# certifi (2018.1.18)
# cffi (1.10.0)
# chardet (3.0.4)
# click (6.7)
# cloudpickle (0.4.0)
# clyent (1.2.2)
# colorama (0.3.7)
# contextlib2 (0.5.5)
# cryptography (2.0.3)
# cycler (0.10.0)
# Cython (0.26.1)
# cytoolz (0.8.2)
# dask (0.15.3)
# datashape (0.5.4)
# decorator (4.1.2)
# distributed (1.19.1)
# docutils (0.14)
# entrypoints (0.2.3)
# environment-kernels (1.1)
# et-xmlfile (1.0.1)
# fastcache (1.0.2)
# filelock (2.0.12)
# Flask (0.12.2)
# Flask-Cors (3.0.3)
# gevent (1.2.2)
# glob2 (0.5)
# gmpy2 (2.0.8)
# ...
